# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df0 = pd.read_excel('Multiple1.xlsx')

# %%
df0
# Out:
#           Date  Growth rate  FDI (Bil USD)  Export (Bil USD)  Import (Bil USD)
# 0   1971-12-01     0.067208       1.103339         36.398285         40.706506
# 1   1972-12-01     0.104308       1.897271         43.630361         48.506788
# 2   1973-12-01     0.097270       2.102302         61.171398         65.125982
# 3   1974-12-01     0.099476       2.176992         81.209935         83.342710
# 4   1975-12-01     0.095061       0.690497         83.951060         92.221048
# 5   1976-12-01     0.097774       1.321370         93.928513        105.502002
# 6   1977-12-01     0.099441       0.949984        107.969326        120.844285
# 7   1978-12-01     0.108671       1.603459        130.594791        144.716339
# 8   1979-12-01     0.127499       1.732552        157.096457        188.607428
# 9   1980-12-01     0.092643      -0.186573        176.955789        220.779619
# 10  1981-12-01     0.096347      -0.415840        161.173729        192.499821
# 11  1982-12-01     0.042083       0.468264        162.071569        182.634123
# 12  1983-12-01     0.066370       0.997855        156.382688        179.447419
# 13  1984-12-01     0.069668       0.590664        157.534514        177.776127
# 14  1985-12-01     0.052418       0.531108        168.036205        182.960451
# 15  1986-12-01     0.042018       1.192025        222.718701        226.593531
# 16  1987-12-01     0.049663       1.620171        268.502189        272.700550
# 17  1988-12-01     0.072240      -1.508575        295.521330        300.374453
# 18  1989-12-01     0.072887       5.173426        311.964421        320.591549
# 19  1990-12-01     0.106955       2.556703        404.575941        407.976034
# 20  1991-12-01     0.064661       4.741535        442.284031        451.396582
# 21  1992-12-01     0.026243      -2.137728        473.095805        483.784596
# 22  1993-12-01     0.021156       0.479814        420.757128        419.718443
# 23  1994-12-01     0.058351       7.517249        465.506810        461.900687
# 24  1995-12-01     0.027971      12.041505        568.725263        558.205268
# 25  1996-12-01     0.028434      15.591798        570.870808        553.029633
# 26  1997-12-01     0.023519      18.638444        560.966614        537.123844
# 27  1998-12-01     0.022814      29.526509        591.248194        563.734578
# 28  1999-12-01     0.047779      86.035665        591.540592        579.415086
# 29  2000-12-01     0.029963     248.007397        599.415884        596.124931
# 30  2001-12-01     0.048936      56.948542        619.095302        587.472931
# 31  2002-12-01     0.034361      51.268215        674.217956        586.295878
# 32  2003-12-01     0.028099      65.401516        819.022573        724.816027
# 33  2004-12-01     0.030135     -20.408420       1003.255525        857.162900
# 34  2005-12-01     0.029653      59.835195       1083.100361        935.106330
# 35  2006-12-01     0.083938      87.444159       1239.754109       1077.694141
# 36  2007-12-01     0.051962      50.847184       1482.170819       1250.516014
# 37  2008-12-01     0.019366      30.954735       1633.721986       1407.175919
# 38  2009-12-01    -0.010598      56.701917       1295.234787       1124.968047
# 39  2010-12-01     0.064754      86.037502       1445.674191       1266.947084
# 40  2011-12-01     0.052954      97.535404       1687.123287       1503.342048
# 41  2012-12-01     0.024829      65.443088       1633.411861       1418.237280
# 42  2013-12-01     0.054114      67.199694       1695.362721       1480.413473
# 43  2014-12-01     0.039246      19.488312       1771.815763       1514.761100
# 44  2015-12-01     0.023448      62.422465       1574.770573       1319.856011
# 45  2016-12-01     0.054815      64.707795       1597.589469       1341.796311
# 46  2017-12-01     0.058763     118.225590       1738.342098       1480.683285
# 47  2018-12-01     0.025183     167.955928       1877.737747       1634.017079

# %%
df0.head()
# Out:
#          Date  Growth rate  FDI (Bil USD)  Export (Bil USD)  Import (Bil USD)
# 0  1971-12-01     0.067208       1.103339         36.398285         40.706506
# 1  1972-12-01     0.104308       1.897271         43.630361         48.506788
# 2  1973-12-01     0.097270       2.102302         61.171398         65.125982
# 3  1974-12-01     0.099476       2.176992         81.209935         83.342710
# 4  1975-12-01     0.095061       0.690497         83.951060         92.221048

# %%
df1 = df0.drop("Date", axis=1)

# %%
df1.head()
# Out:
#    Growth rate  FDI (Bil USD)  Export (Bil USD)  Import (Bil USD)
# 0     0.067208       1.103339         36.398285         40.706506
# 1     0.104308       1.897271         43.630361         48.506788
# 2     0.097270       2.102302         61.171398         65.125982
# 3     0.099476       2.176992         81.209935         83.342710
# 4     0.095061       0.690497         83.951060         92.221048

# %%
import statsmodels.api as sn

# %%
X_multi = df1.drop("Growth rate", axis=1)

# %%
X_multi.head()
# Out:
#    FDI (Bil USD)  Export (Bil USD)  Import (Bil USD)
# 0       1.103339         36.398285         40.706506
# 1       1.897271         43.630361         48.506788
# 2       2.102302         61.171398         65.125982
# 3       2.176992         81.209935         83.342710
# 4       0.690497         83.951060         92.221048

# %%
y_multi = df['Growth rate']

# %%
y_multi.head()
# Out:
# 0    0.067208
# 1    0.104308
# 2    0.097270
# 3    0.099476
# 4    0.095061
# Name: Growth rate, dtype: float64

# %%
X_multi_cons = sn.add_constant(X_multi)

# %%
X_multi_cons.head()
# Out:
#    const  FDI (Bil USD)  Export (Bil USD)  Import (Bil USD)
# 0    1.0       1.103339         36.398285         40.706506
# 1    1.0       1.897271         43.630361         48.506788
# 2    1.0       2.102302         61.171398         65.125982
# 3    1.0       2.176992         81.209935         83.342710
# 4    1.0       0.690497         83.951060         92.221048

# %%
lm_multi = sn.OLS(y_multi, X_multi_cons).fit()

# %%
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Growth rate   R-squared:                       0.322
# Model:                            OLS   Adj. R-squared:                  0.275
# Method:                 Least Squares   F-statistic:                     6.950
# Date:                Tue, 27 Apr 2021   Prob (F-statistic):           0.000627
# Time:                        00:57:42   Log-Likelihood:                 108.46
# No. Observations:                  48   AIC:                            -208.9
# Df Residuals:                      44   BIC:                            -201.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0897      0.010      9.016      0.000       0.070       0.110
# FDI (Bil USD)     1.424e-05   9.98e-05      0.143      0.887      -0.000       0.000
# Export (Bil USD)     0.0002      0.000      1.607      0.115   -5.49e-05       0.000
# Import (Bil USD)    -0.0003      0.000     -1.793      0.080      -0.001    3.63e-05
# ==============================================================================
# Omnibus:                        2.051   Durbin-Watson:                   1.199
# Prob(Omnibus):                  0.359   Jarque-Bera (JB):                1.436
# Skew:                           0.189   Prob(JB):                        0.488
# Kurtosis:                       2.242   Cond. No.                     3.19e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.19e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X = np.array(X_multi)
Y = np.array(y_multi)

fig = plt.figure(1)
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:, 0], X[:, 1], Y)
ax.set_xlabel('FDI (Bil USD)')
ax.set_ylabel('Import (Bil USD)')
ax.set_zlabel('Export (Bil USD)')
# Out:
# Text(0.5, 0, 'Export (Bil USD)')

# %%
# Use Linear Algebra to solve
a = np.linalg.solve(np.dot(X.T, X), np.dot(X.T, Y))
predictedY = np.dot(X, a)

# calculate the r-squared
SSres = Y - predictedY
SStot = Y - Y.mean()
rSquared = 1 - (SSres.dot(SSres) / SStot.dot(SStot))
print("the r-squared is: ", rSquared)
print("the coefficient (value of a) for age, weight, constant is: ", a)

# create a wiremesh for the plane that the predicted values will lie
xx, yy, zz = np.meshgrid(X[:, 0], X[:, 1], X[:, 2])
combinedArrays = np.vstack((xx.flatten(), yy.flatten(), zz.flatten())).T
Z = combinedArrays.dot(a)
# Out:
# the r-squared is:  -0.9320379726589989
# the coefficient (value of a) for age, weight, constant is:  [-0.00021663 -0.0007382   0.00089631]

# %%
fig = plt.figure(2)
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:, 0], X[:, 1], Y, color='r', label='Actual Growth')
ax.scatter(X[:, 0], X[:, 1], predictedY, color='g', label='Predicted Growth')
ax.plot_trisurf(combinedArrays[:, 0], combinedArrays[:, 1], Z, alpha=0.5)
ax.set_xlabel('FDI (Bil USD)')
ax.set_ylabel('Import (Bil USD)')
ax.set_zlabel('Export (Bil USD)')
ax.legend()
plt.show()
