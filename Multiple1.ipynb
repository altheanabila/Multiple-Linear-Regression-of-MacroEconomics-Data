#          Date  Growth rate  Export (Bil USD)  Import (Bil USD)
# 0  1971-12-31     0.067208         36.398285         40.706506
# 1  1972-12-31     0.104308         43.630361         48.506788
# 2  1973-12-31     0.097270         61.171398         65.125982
# 3  1974-12-31     0.099476         81.209935         83.342710
# 4  1975-12-31     0.095061         83.951060         92.221048

# %%
df1 = df0.drop("Date", axis=1)

# %%
df1.head()
# Out:
#    Growth rate  Export (Bil USD)  Import (Bil USD)
# 0     0.067208         36.398285         40.706506
# 1     0.104308         43.630361         48.506788
# 2     0.097270         61.171398         65.125982
# 3     0.099476         81.209935         83.342710
# 4     0.095061         83.951060         92.221048

# %%
import statsmodels.api as sn

# %%
X_multi = df1.drop("Growth rate", axis=1)

# %%
X_multi.head()
# Out:
#    Export (Bil USD)  Import (Bil USD)
# 0         36.398285         40.706506
# 1         43.630361         48.506788
# 2         61.171398         65.125982
# 3         81.209935         83.342710
# 4         83.951060         92.221048

# %%
y_multi = df['Growth rate']

# %%
y_multi.head()
# Out:
# 0    0.067208
# 1    0.104308
# 2    0.097270
# 3    0.099476
# 4    0.095061
# Name: Growth rate, dtype: float64

# %%
X_multi_cons = sn.add_constant(X_multi)

# %%
X_multi_cons.head()
# Out:
#    const  Export (Bil USD)  Import (Bil USD)
# 0    1.0         36.398285         40.706506
# 1    1.0         43.630361         48.506788
# 2    1.0         61.171398         65.125982
# 3    1.0         81.209935         83.342710
# 4    1.0         83.951060         92.221048

# %%
 lm_multi = sn.OLS(y_multi, X_multi_cons).fit()

# %%
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Growth rate   R-squared:                       0.321
# Model:                            OLS   Adj. R-squared:                  0.291
# Method:                 Least Squares   F-statistic:                     10.65
# Date:                Tue, 27 Apr 2021   Prob (F-statistic):           0.000164
# Time:                        02:28:55   Log-Likelihood:                 108.45
# No. Observations:                  48   AIC:                            -210.9
# Df Residuals:                      45   BIC:                            -205.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0893      0.010      9.394      0.000       0.070       0.108
# Export (Bil USD)     0.0002      0.000      1.649      0.106   -4.67e-05       0.000
# Import (Bil USD)    -0.0003      0.000     -1.859      0.070      -0.001    2.37e-05
# ==============================================================================
# Omnibus:                        2.061   Durbin-Watson:                   1.196
# Prob(Omnibus):                  0.357   Jarque-Bera (JB):                1.427
# Skew:                           0.181   Prob(JB):                        0.490
# Kurtosis:                       2.237   Cond. No.                     3.08e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.08e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X = np.array(X_multi)
Y = np.array(y_multi)

fig = plt.figure(1)
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:, 0], X[:, 1], Y)
ax.set_xlabel('Import (Bil USD)')
ax.set_ylabel('Export (Bil USD)')
ax.set_zlabel('Growth rate')
# Out:
# Text(0.5, 0, 'Growth rate')

# %%
fig = plt.figure(2)
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:, 0], X[:, 1], Y, color='r', label='Actual Growth')
ax.scatter(X[:, 0], X[:, 1], predictedY, color='g', label='Predicted Growth')
ax.plot_trisurf(combinedArrays[:, 0], combinedArrays[:, 1], Z, alpha=0.5)
ax.set_xlabel('Import (Bil USD)')
ax.set_ylabel('Export (Bil USD)')
ax.set_zlabel('Growth rate')
ax.legend()
plt.show()
